# %%
import word2vec as w2v

# %%
calculated = w2v.Word2Vec()
calculated.loadFromFile("./models_v3/calculated_model_43000_100.txt")

# %%
raw = w2v.Word2Vec()
raw.loadFromFile("./test_v3/model_43000.txt")

# %%
w2v.plot(calculated.words_df, ['donald', 'trump', 'vegas', 'wedding', 'episode'])
# Out:
# dim too large using PCA

# %%
w2v.plot(raw.words_df, ['donald', 'trump', 'vegas', 'wedding', 'episode'])
# Out:
# dim too large using PCA
